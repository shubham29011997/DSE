# %%
# type your code here
# type your code here
# import 'Pandas' 
import pandas as pd 

# import 'Numpy' 
import numpy as np

# import subpackage of Matplotlib
import matplotlib.pyplot as plt

# import 'Seaborn' 
import seaborn as sns

# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# display all columns of the dataframe
pd.options.display.max_columns = None

# display all rows of the dataframe
pd.options.display.max_rows = None
 
# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.6f}'.format

# import train-test split 
from sklearn.model_selection import train_test_split

# import various functions from statsmodel to perform linear regression
import statsmodels
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
from statsmodels.tools.eval_measures import rmse

# import various functions from scipy
from scipy import stats
from scipy.stats import shapiro

# 'metrics' from sklearn is used for evaluating the model performance
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor

# %%
# type your code here
df= pd.read_csv('~/Desktop/New folder (3)/reg take/Day 01/car_data.csv')
# display first five observations using head()
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       3.350000       5.590000       27000    Petrol
# 1      sx4  2013       4.750000       9.540000       43000    Diesel
# 2     ciaz  2017       7.250000       9.850000        6900    Petrol
# 3  wagon r  2011       2.850000       4.150000        5200    Petrol
# 4    swift  2014       4.600000       6.870000       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# type your code here'
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df[''].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
# type your code here
y = df['Selling_Price']
df_ = df.drop('Selling_Price',axis = 1)
df_ = df_.drop('Car_Name',axis = 1)
df_ = df_[0:]

df_m = sm.add_constant(df_)
x = pd.get_dummies(df_m,drop_first = True)
model = sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     274.3
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):          5.71e-131
# Time:                        10:11:23   Log-Likelihood:                -593.62
# No. Observations:                 301   AIC:                             1205.
# Df Residuals:                     292   BIC:                             1239.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# type your code here
vif = pd.DataFrame()
df_num = df.select_dtypes(include = np.number)
vif['feat'] = df_num.columns
vif['vif'] = [variance_inflation_factor(df_num.values,i)for i in range (df_num.shape[1])]
print(vif)
# Out:
#             feat      vif
# 0           Year 2.780556
# 1  Selling_Price 9.355028
# 2  Present_Price 9.339093
# 3     Kms_Driven 2.215973
# 4          Owner 1.074269

# %%
# type your code heredf
df_.columns
df1 = df_.iloc[:,[1,4]]
df1 = pd.get_dummies(df1)
y = df['Selling_Price']
df1 = sm.add_constant(df1)
mode = sm.OLS(y,df1).fit()
mode.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     548.4
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):          1.34e-100
# Time:                        10:11:24   Log-Likelihood:                -683.71
# No. Observations:                 301   AIC:                             1373.
# Df Residuals:                     298   BIC:                             1385.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# type your code here
df_['feature']  = df_['Present_Price']*df['Year']
df2 = df_.iloc[:,[0,1]]
y = df['Selling_Price']
df2 = sm.add_constant(df2)
modell = sm.OLS(y,df2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     274.3
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):          5.71e-131
# Time:                        10:11:25   Log-Likelihood:                -593.62
# No. Observations:                 301   AIC:                             1205.
# Df Residuals:                     292   BIC:                             1239.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# type your code here
df3 = pd.get_dummies(df_['Fuel_Type'])
df3 = sm.add_constant(df3)
y = df['Selling_Price']
mod1 = sm.OLS(y,df3).fit()
mod1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     65.41
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):           2.80e-24
# Time:                        10:11:25   Log-Likelihood:                -861.21
# No. Observations:                 301   AIC:                             1728.
# Df Residuals:                     298   BIC:                             1740.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1607      0.767      5.424      0.000       2.651       5.670
# ...

# %%
# type your code here
df4 = pd.get_dummies(df_['Transmission'])
df4 = sm.add_constant(df4)
y = df['Selling_Price']
mod2 = sm.OLS(y,df4).fit()
mod2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     46.58
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):           4.90e-11
# Time:                        10:11:26   Log-Likelihood:                -894.20
# No. Observations:                 301   AIC:                             1792.
# Df Residuals:                     299   BIC:                             1800.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4507      0.268     16.604      0.000       3.923       4.978
# ...

# %%
# type your code here
y = df['Selling_Price']
x = sm.add_constant(df_['Present_Price'])
mode = sm.OLS(y,x).fit()
mode.summary()
mode.conf_int(alpha = 0.01)
# Out:
#                      0        1
# const         0.234343 1.202712
# Present_Price 0.474812 0.558886

# %%
mode.conf_int(alpha = 0.05)
# Out:
#                      0        1
# const         0.350972 1.086083
# Present_Price 0.484938 0.548760

# %%
# type your code here
y = df['Selling_Price']
x = sm.add_constant(df_['Present_Price'])
mode = sm.OLS(y,x).fit()
mode.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     1016.
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):           3.60e-98
# Time:                        10:17:35   Log-Likelihood:                -693.08
# No. Observations:                 301   AIC:                             1390.
# Df Residuals:                     299   BIC:                             1398.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
sc = StandardScaler()
df_s = pd.get_dummies(df_,drop_first=True)
# dfs = sc.fit_transform(dfs)
df_s
# Out:
#      Year  Present_Price  Kms_Driven  Owner       feature  Fuel_Type_Diesel  \
# 0    2014       5.590000       27000      0  11258.260000                 0
# 1    2013       9.540000       43000      0  19204.020000                 1
# 2    2017       9.850000        6900      0  19867.450000                 0
# 3    2011       4.150000        5200      0   8345.650000                 0
# 4    2014       6.870000       42450      0  13836.180000                 1
# 5    2018       9.830000        2071      0  19836.940000                 1
# 6    2015       8.120000       18796      0  16361.800000                 0
# 7    2015       8.610000       33429      0  17349.150000                 1
# 8    2016       8.890000       20273      0  17922.240000                 1
# 9    2015       8.920000       42367      0  17973.800000                 1
# 10   2017       3.600000        2135      0   7261.200000                 0
# ...

# %%
# type your code here
y = df['Selling_Price'] 
x = pd.get_dummies(df_['Fuel_Type'],drop_first = True)
z = pd.get_dummies(df_['Seller_Type'],drop_first= True)
r = pd.get_dummies(df_['Transmission'],drop_first=True)
df_['add'] = df_s['Year'] + df_s['Present_Price'] + df_s['Kms_Driven'] + df_s['Owner'] + x + z + r
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [41], in <cell line: 6>()
#       4 z = pd.get_dummies(df_['Seller_Type'],drop_first= True)
#       5 r = pd.get_dummies(df_['Transmission'],drop_first=True)
# ----> 6 df_['add'] = df_s['Year'] + df_s['Present_Price'] + df_s['Kms_Driven'] + df_s['Owner'] + x + z + r
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
