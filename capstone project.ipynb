# %%
# !pip install jupyterthemes
# !jt -t oceans16

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_csv('~/Desktop/New folder (6)/credit_train/credit_train.csv')
test = pd.read_csv('~/Desktop/New folder (6)/credit_test.csv')

# %%
train.shape,test.shape
# Out:
# ((100514, 19), (10000, 18))

# %%
test.dropna(subset=['Loan ID'], inplace = True)

# %%
train.dropna(subset=['Loan Status'], inplace = True)

# %%
null = df[train['Loan ID'].isnull()]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12008\3173273183.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   null = df[train['Loan ID'].isnull()]

# %%
# train = train-null

# %%
train
# Out:
#                                     Loan ID  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048
# 1      4771cc26-131a-45db-b5aa-537ea4ba5342
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4      d4062e70-befa-4995-8643-a0de73938182
# ...                                     ...
# 99995  3f94c18c-ba8f-45d0-8610-88a684a410a9
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998  81ab928b-d1a5-4523-9a3c-271ebb01b4fb
# 99999  c63916c6-6d46-47a9-949a-51d09af4414f
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 0      981165ec-3274-42f5-a3b4-d104041a9ca9            0             445412.0
# 1      2de017a3-2e01-49cb-a581-08169e83be29            0             262328.0
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725            0           99999999.0
# 3      e777faab-98ae-45af-9a86-7ce5b33b1011            0             347666.0
# ...

# %%
df = pd.concat([train,test],ignore_index = False)

# %%
df
# Out:
#                                    Loan ID  \
# 0     14dd8831-6af5-400b-83ec-68e61888a048
# 1     4771cc26-131a-45db-b5aa-537ea4ba5342
# 2     4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3     77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4     d4062e70-befa-4995-8643-a0de73938182
# ...                                    ...
# 9995  c4ab66f9-833c-43b8-879c-4f8bcb64dd14
# 9996  bbd3a392-01b4-4e0e-9c28-b2a4a39beac7
# 9997  da9870de-4280-46a3-8fc6-91cfe5bfde9d
# 9998  0cc8e0e0-1bc6-49d7-ad0f-0598b647458f
# 9999  14f94b64-26c4-48fd-b916-1388d7adcc1d
#
#                                Customer ID Loan Status  Current Loan Amount  \
# 0     981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1     2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2     5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3     e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
df[df['Loan ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Loan ID, Customer ID, Loan Status, Current Loan Amount, Term, Credit Score, Annual Income, Years in current job, Home Ownership, Purpose, Monthly Debt, Years of Credit History, Months since last delinquent, Number of Open Accounts, Number of Credit Problems, Current Credit Balance, Maximum Open Credit, Bankruptcies, Tax Liens]
# Index: []

# %%
# df.dropna(subset=['Loan Status'], inplace = True)

# %%
df.shape
# Out:
# (110000, 19)

# %%
# df.head

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       110000 non-null  object
#  1   Customer ID                   110000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           110000 non-null  float64
#  4   Term                          110000 non-null  object
#  5   Credit Score                  88865 non-null   float64
#  6   Annual Income                 88865 non-null   float64
#  7   Years in current job          105351 non-null  object
#  8   Home Ownership                110000 non-null  object
#  9   Purpose                       110000 non-null  object
#  10  Monthly Debt                  110000 non-null  float64
#  11  Years of Credit History       110000 non-null  float64
# ...

# %%
(df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)
# Out:
# Months since last delinquent    53.133636
# Credit Score                    19.213636
# Annual Income                   19.213636
# Loan Status                      9.090909
# Years in current job             4.226364
# Bankruptcies                     0.205455
# Tax Liens                        0.010000
# Maximum Open Credit              0.001818
# Current Credit Balance           0.000000
# Number of Credit Problems        0.000000
# Number of Open Accounts          0.000000
# Loan ID                          0.000000
# Years of Credit History          0.000000
# Monthly Debt                     0.000000
# Customer ID                      0.000000
# Home Ownership                   0.000000
# Term                             0.000000
# Current Loan Amount              0.000000
# Purpose                          0.000000
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,7))
sns.heatmap(df.isnull(), yticklabels=False, cmap="viridis", cbar=False,ax=ax)
plt.show()

# %%
df.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.096655
# Credit Score                            -0.096655      1.000000
# Annual Income                            0.012816     -0.020050
# Monthly Debt                            -0.008013     -0.003288
# Years of Credit History                  0.019465     -0.010289
# Months since last delinquent             0.010217     -0.002687
# Number of Open Accounts                  0.001149      0.005273
# Number of Credit Problems               -0.002417     -0.001904
# Current Credit Balance                   0.003587     -0.001618
# Maximum Open Credit                     -0.001098     -0.002965
# Bankruptcies                            -0.001521     -0.005709
# Tax Liens                                0.000138      0.005285
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.012816     -0.008013
# ...

# %%
plt.scatter(x = df['Current Loan Amount'],y = df['Annual Income'])

# %%
# sns.scatterplot(y = df['Current Loan Amount'],x = df[''])

# %%
sns.histplot(df['Annual Income'])
# Out:
# <AxesSubplot:xlabel='Annual Income', ylabel='Count'>

# %%
df.std()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12008\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Current Loan Amount             3.176716e+07
# Credit Score                    1.475582e+03
# Annual Income                   1.063920e+06
# Monthly Debt                    1.219556e+04
# Years of Credit History         7.015575e+00
# Months since last delinquent    2.196532e+01
# Number of Open Accounts         5.011093e+00
# Number of Credit Problems       4.843888e-01
# Current Credit Balance          3.772773e+05
# Maximum Open Credit             8.014002e+06
# Bankruptcies                    3.512897e-01
# Tax Liens                       2.610544e-01
# dtype: float64

# %%
df.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.100000e+05  88865.000000   8.886500e+04  110000.000000
# mean          1.174621e+07   1076.594644   1.377449e+06   18468.526823
# std           3.176716e+07   1475.581902   1.063920e+06   12195.564391
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.795860e+05    705.000000   8.488440e+05   10211.930000
# 50%           3.120260e+05    724.000000   1.173459e+06   16202.440000
# 75%           5.239300e+05    741.000000   1.651670e+06   23997.522500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            110000.000000                  51553.000000
# mean                 18.202485                     34.907086
# std                   7.015575                     21.965315
# min                   3.600000                      0.000000
# ...

# %%
df['Months since last delinquent'].value_counts().sort_values(ascending=False)
# Out:
# 12.0     994
# 13.0     991
# 15.0     974
# 14.0     944
# 8.0      943
#         ...
# 100.0      1
# 148.0      1
# 152.0      1
# 114.0      1
# 143.0      1
# Name: Months since last delinquent, Length: 116, dtype: int64

# %%
df['Loan Status'].value_counts()
# Out:
# 0.0    77361
# 1.0    22639
# Name: Loan Status, dtype: int64

# %%
df['Tax Liens'].value_counts()
# Out:
# 0.0     107872
# 1.0       1474
# 2.0        405
# 3.0        124
# 4.0         66
# 5.0         18
# 6.0         12
# 7.0          7
# 9.0          5
# 11.0         2
# 8.0          2
# 15.0         1
# 10.0         1
# Name: Tax Liens, dtype: int64

# %%
df['Bankruptcies'].value_counts()
# Out:
# 0.0    97669
# 1.0    11497
# 2.0      463
# 3.0      107
# 4.0       27
# 5.0        8
# 6.0        2
# 7.0        1
# Name: Bankruptcies, dtype: int64

# %%
train['Loan Status'].replace(('Fully Paid','Charged Off'),(0,1),inplace=True)

# %%
df['Loan Status']
# Out:
# 0         Fully Paid
# 1         Fully Paid
# 2         Fully Paid
# 3         Fully Paid
# 4         Fully Paid
#              ...
# 109995           NaN
# 109996           NaN
# 109997           NaN
# 109998           NaN
# 109999           NaN
# Name: Loan Status, Length: 110000, dtype: object

# %%
df[df['Loan Status'] == 1].describe()
# Out:
#        Loan Status  Current Loan Amount  Credit Score  Annual Income  \
# count      22639.0         22639.000000  17210.000000   1.721000e+04
# mean           1.0        324975.226821   2402.296862   1.267790e+06
# std            0.0        185905.916383   2826.692993   1.506251e+06
# min            1.0         21450.000000    585.000000   7.662700e+04
# 25%            1.0        179883.000000    705.000000   7.787435e+05
# 50%            1.0        286726.000000    730.000000   1.085812e+06
# 75%            1.0        439835.000000   6500.000000   1.507579e+06
# max            1.0        789250.000000   7510.000000   1.655574e+08
#
#         Monthly Debt  Years of Credit History  Months since last delinquent  \
# count   22639.000000             22639.000000                  10409.000000
# mean    18650.565494                17.891736                     34.339226
# std     12171.978272                 7.090022                     22.241433
# ...

# %%
# x = []
# c = 1
# for i in df['Credit Score'].values:
#     if i>850:
#         x = i/10
#         c+=1
#         x

# %%
df['Credit Score'].values
# Out:
# array(['Good', nan, 'Exception', ..., nan, nan, nan], dtype=object)

# %%
df['Credit Score'].min()
# Out:
# 585.0

# %%
df['Credit Score'] = df['Credit Score'].apply(lambda val: (val /10) if val>850 else val)

# %%
df['Credit Score'] = df['Credit Score'].apply(lambda val: "Poor" if np.isreal(val) and (val >= 585 and val <670) else val)
# df['Credit Score'] = df['Credit Score'].apply(lambda val: "Average" if np.isreal(val) and (val >= 580 and val < 670) else val)
df['Credit Score'] = df['Credit Score'].apply(lambda val: "Good" if np.isreal(val) and (val >= 670 and val < 740) else val)
df['Credit Score'] = df['Credit Score'].apply(lambda val: "Exception" if np.isreal(val) and (val >= 740 and val < 850) else val)
# df['Credit Score'] = df['Credit Score'].apply(lambda val: "Exceptional" if np.isreal(val) and (val >= 740 and val <= 850) else val)

# %%
df['Credit Score'].value_counts()
# Out:
# Good         83042
# Exception    20335
# Poor          6623
# Name: Credit Score, dtype: int64

# %%
df['Credit Score'].isnull().sum()
# Out:
# 867

# %%
df['Bankruptcies'].mode()
# Out:
# 0    0.0
# Name: Bankruptcies, dtype: float64

# %%
df['Years in current job'] = df['Years in current job'].fillna('10+ years')

# %%
df['Term'] = df['Term'].fillna('Short Term')
# df['Credit Score'] = df['Credit Score'].fillna('Short Term')

# %%
df['Current Loan Amount'] = df['Current Loan Amount'].fillna(df['Current Loan Amount'].mean())
df['Annual Income'] = df['Annual Income'].fillna(df['Annual Income'].mean())

# %%
df['Maximum Open Credit'] = df['Maximum Open Credit'].fillna(df['Maximum Open Credit'].mean())
df['Tax Liens'] = df['Tax Liens'].fillna(0)

# %%
df['Bankruptcies'] = df['Bankruptcies'].fillna(0)

# %%
df['Bankruptcies'].mode()
# Out:
# 0    0.0
# Name: Bankruptcies, dtype: float64

# %%
# df[df['Term'] == 'Short Term']['Credit Score'].mean()

# %%
cscoredf = df[df['Term']=='Short Term']
stermAVG = cscoredf['Credit Score'].mean()
print(stermAVG)
# 724.6209386906824
lscoredf = df[df['Term']=='Long Term']
ltermAVG = lscoredf['Credit Score'].mean()
print(ltermAVG)
# Out:
# 724.638077552562
# 695.4592630622803

# %%
# df.loc[(df.Term =='Short Term') & (df['Credit Score'].isnull()),'Credit Score']=df[df['Term'] == 'Short Term']['Credit Score'].fillna(df[df['Term'] == 'Short Term']['Credit Score'].mean())

# %%
# df[df['Term'] == 'Long Term']['Credit Score'] =df[df['Term'] == 'Long Term']['Credit Score'].fillna(695)

# %%
df.loc[(df.Term =='Short Term') & (df['Credit Score'].isnull()),'Credit Score'] = stermAVG
df.loc[(df.Term =='Long Term') & (df['Credit Score'].isnull()),'Credit Score'] = ltermAVG

# %%
# new = df["Years in current job"].str.split(" ", n = 1, expand = True)
 
# # making separate first name column from new data frame
# df["Years in current job"]= new[0]
 
# # making separate last name column from new data frame
# df["Years"]= new[1]

# %%
df['Years in current job'].value_counts()
# Out:
# 10+ years    34206
# 2 years      10050
# 3 years       9035
# < 1 year      8959
# 5 years       7483
# 1 year        7108
# 4 years       6756
# 6 years       6252
# 7 years       6131
# 8 years       5054
# 9 years       4317
# Name: Years in current job, dtype: int64

# %%
# df['Years in current job'] = df['Years in current job'].apply(lambda val: "Poor" if np.isreal(val) and (val >= 585 and val <670) else val)
# # df['Credit Score'] = df['Credit Score'].apply(lambda val: "Average" if np.isreal(val) and (val >= 580 and val < 670) else val)
# df['Years in current job'] = df['Years in current job'].apply(lambda val: "Good" if np.isreal(val) and (val >= 670 and val < 740) else val)
# df['Years in current job'] = df['Credit Score'].apply(lambda val: "Exception" if np.isreal(val) and (val >= 740 and val < 850) else val)

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# df.groupby('Tax Liens').mean()

# %%
# df['Tax Liens'].value_counts()

# %%
# df['Bankruptcies'].value_counts()

# %%
# df.groupby('Bankruptcies').mean()

# %%
cscoredf = df[df['Term']=='Short Term']
stermAVG = cscoredf['Months since last delinquent'].mean()
print(stermAVG)
# 724.6209386906824
lscoredf = df[df['Term']=='Long Term']
ltermAVG = lscoredf['Months since last delinquent'].mean()
print(ltermAVG)
# Out:
# 35.10380873247742
# 34.39181409716372

# %%
df.loc[(df.Term =='Short Term') & (df['Months since last delinquent'].isnull()),'Months since last delinquent'] = stermAVG
df.loc[(df.Term =='Long Term') & (df['Months since last delinquent'].isnull()),'Months since last delinquent'] = ltermAVG

# %%
df['Years in current job']=df['Years in current job'].str.extract(r"(\d+)")
df['Years in current job'] = df['Years in current job'].astype(float)

# %%
meanxoutlier = df[df['Annual Income'] < 99999999.00 ]['Annual Income'].mean()
stddevxoutlier = df[df['Annual Income'] < 99999999.00 ]['Annual Income'].std()
poorline = meanxoutlier -  stddevxoutlier
richline = meanxoutlier + stddevxoutlier

# %%
lmeanxoutlier = df[df['Current Loan Amount'] < 99999999.00 ]['Current Loan Amount'].mean()
lstddevxoutlier = df[df['Current Loan Amount'] < 99999999.00 ]['Current Loan Amount'].std()
lowrange = lmeanxoutlier - lstddevxoutlier
highrange = lmeanxoutlier + lstddevxoutlier
print(lowrange, highrange)
# Out:
# 125948.5136545776 498036.4464719332

# %%
df['Current Loan Amount'] = df['Current Loan Amount'].apply(lambda x: "Small Loan" if x<=lowrange else ("Medium Loan" if x>lowrange and x<highrange else "Big Loan"))

# %%
df['Annual Income'] = df['Annual Income'].apply(lambda x: "Low Income" if x<=poorline else ("Average Income" if x>poorline and x<richline else "High Income"))

# %%
df.reset_index(inplace=True, drop=True)

# %%
num = df.select_dtypes(np.number)
cat = df.select_dtypes(object)

# %%
# num.drop(['Loan Status'],axis = 1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
nm = scale.fit_transform(num)
num = pd.DataFrame(nm,columns =num.columns)

# %%
num.columns
# Out:
# Index(['Years in current job', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
num = num[['Years in current job', 'Monthly Debt', 'Years of Credit History',
       'Months since last delinquent', 'Number of Open Accounts',
       'Number of Credit Problems', 'Current Credit Balance',
       'Maximum Open Credit', 'Bankruptcies', 'Tax Liens']].apply(lambda x: np.log(x))
# Out:
# D:\New folder\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
num
# Out:
#         Years in current job  Monthly Debt  Years of Credit History  \
# 0                   0.526941     -1.086776                -0.142895
# 1                   1.095141      1.215813                 0.413014
# 2                   0.526941      0.879996                -0.470738
# 3                  -0.893559     -0.797558                -0.884106
# 4                  -0.325359      0.178031                -1.725096
# ...                      ...           ...                      ...
# 109995             -0.041259     -1.121160                -0.812836
# 109996             -0.609459     -0.497450                -1.183442
# 109997              1.095141     -1.157320                 1.282511
# 109998              1.095141     -0.511363                -0.199911
# 109999             -0.041259     -0.510755                 0.213457
#
#         Months since last delinquent  Number of Open Accounts  \
# 0                           0.013126                -1.022634
# ...

# %%
cat.drop(['Loan ID','Customer ID'],axis = 1,inplace=True)

# %%
cat.drop('Loan Status',axis = 1,inplace = True)

# %%
cat.drop('Home Ownership',axis = 1,inplace = True)

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110000 entries, 0 to 109999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Current Loan Amount  110000 non-null  object
#  1   Term                 110000 non-null  object
#  2   Credit Score         110000 non-null  object
#  3   Annual Income        110000 non-null  object
# dtypes: object(4)
# memory usage: 3.4+ MB

# %%
cat
# Out:
#        Current Loan Amount        Term Credit Score   Annual Income
# 0              Medium Loan  Short Term         Good  Average Income
# 1              Medium Loan  Short Term         Good  Average Income
# 2                 Big Loan  Short Term    Exception     High Income
# 3              Medium Loan   Long Term         Good  Average Income
# 4              Medium Loan  Short Term         Good  Average Income
# ...                    ...         ...          ...             ...
# 109995         Medium Loan  Short Term         Good  Average Income
# 109996         Medium Loan  Short Term         Good  Average Income
# 109997         Medium Loan   Long Term         Good  Average Income
# 109998            Big Loan  Short Term         Good  Average Income
# 109999            Big Loan  Short Term    Exception  Average Income
#
# [110000 rows x 4 columns]

# %%
cat = pd.get_dummies(cat,drop_first=True)

# %%
from category_encoders import TargetEncoder
Targetenc = TargetEncoder()
# transforming the column after fitting
values = Targetenc.fit_transform(X = df['Purpose'], y = df['Loan Status'])
# Out:
# D:\New folder\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# D:\New folder\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %%
# num['Purpose'] = values['Purpose']

# %%
cat = cat.drop('Purpose',axis = 1)

# %%
num = pd.concat([num, values], axis = 1)
num.head(10)
# Out:
#    Years in current job  Monthly Debt  Years of Credit History  \
# 0              0.526941     -1.086776                -0.142895
# 1              1.095141      1.215813                 0.413014
# 2              0.526941      0.879996                -0.470738
# 3             -0.893559     -0.797558                -0.884106
# 4             -0.325359      0.178031                -1.725096
# 5              1.095141     -0.172259                -0.128641
# 6             -1.461759     -0.624283                 0.199203
# 7             -1.461759     -0.300307                -1.425761
# 8             -1.177659      0.015723                 0.626824
# 9             -1.461759      1.706302                -0.613279
#
#    Months since last delinquent  Number of Open Accounts  \
# 0                      0.013126                -1.022634
# 1                     -1.789122                 4.764552
# 2                     -0.392743                 1.372064
# ...

# %%
# cat.drop('Home Ownership',axis = 1,inplace = True)

# %%
num
# Out:
#         Years in current job  Monthly Debt  Years of Credit History  \
# 0                   0.526941     -1.086776                -0.142895
# 1                   1.095141      1.215813                 0.413014
# 2                   0.526941      0.879996                -0.470738
# 3                  -0.893559     -0.797558                -0.884106
# 4                  -0.325359      0.178031                -1.725096
# ...                      ...           ...                      ...
# 109995             -0.041259     -1.121160                -0.812836
# 109996             -0.609459     -0.497450                -1.183442
# 109997              1.095141     -1.157320                 1.282511
# 109998              1.095141     -0.511363                -0.199911
# 109999             -0.041259     -0.510755                 0.213457
#
#         Months since last delinquent  Number of Open Accounts  \
# 0                           0.013126                -1.022634
# ...

# %%
df = pd.concat([num,cat],axis = 1)

# %%
df
# Out:
#         Years in current job  Monthly Debt  Years of Credit History  \
# 0                   0.526941     -1.086776                -0.142895
# 1                   1.095141      1.215813                 0.413014
# 2                   0.526941      0.879996                -0.470738
# 3                  -0.893559     -0.797558                -0.884106
# 4                  -0.325359      0.178031                -1.725096
# ...                      ...           ...                      ...
# 109995             -0.041259     -1.121160                -0.812836
# 109996             -0.609459     -0.497450                -1.183442
# 109997              1.095141     -1.157320                 1.282511
# 109998              1.095141     -0.511363                -0.199911
# 109999             -0.041259     -0.510755                 0.213457
#
#         Months since last delinquent  Number of Open Accounts  \
# 0                           0.013126                -1.022634
# ...

# %%
train.drop(['Loan ID','Customer ID'],axis = 1,inplace=True)

# %%
n = train.select_dtypes(np.number)

# %%
plt.rcParams['figure.figsize'] = (20,15)
c=1
for i in num.columns:
    plt.subplot(4,4,c)
    sns.distplot(num[i])
    c+=1
plt.show()
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.drop('Purpose',axis = 1,inplace = True)

# %%
df.drop('Number of Credit Problems',axis = 1,inplace = True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(df.values,i)for i in range(df.shape[1])]

# %%
pd.DataFrame({'VIF':vif[:]},index = df.columns)
# Out:
#                                       VIF
# Years in current job             1.073701
# Monthly Debt                     1.761079
# Years of Credit History          1.138833
# Months since last delinquent     1.011868
# Number of Open Accounts          1.220703
# Current Credit Balance           1.381012
# Maximum Open Credit              1.022299
# Bankruptcies                     1.040107
# Tax Liens                        1.005351
# Current Loan Amount_Medium Loan  3.039213
# Current Loan Amount_Small Loan   1.711593
# Term_Short Term                  2.978862
# Credit Score_Good                2.904945
# Credit Score_Poor                1.110452
# Annual Income_High Income        1.291686
# Annual Income_Low Income         1.148024

# %%
df
# Out:
#         Years in current job  Monthly Debt  Years of Credit History  \
# 0                   0.526941     -1.086776                -0.142895
# 1                   1.095141      1.215813                 0.413014
# 2                   0.526941      0.879996                -0.470738
# 3                  -0.893559     -0.797558                -0.884106
# 4                  -0.325359      0.178031                -1.725096
# ...                      ...           ...                      ...
# 109995             -0.041259     -1.121160                -0.812836
# 109996             -0.609459     -0.497450                -1.183442
# 109997              1.095141     -1.157320                 1.282511
# 109998              1.095141     -0.511363                -0.199911
# 109999             -0.041259     -0.510755                 0.213457
#
#         Months since last delinquent  Number of Open Accounts  \
# 0                           0.013126                -1.022634
# ...

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# %%
newtrain=df.iloc[:train.shape[0]]
newtest=df.iloc[train.shape[0]:]

# %%
newtrain.shape,newtest.shape
# Out:
# ((100000, 16), (10000, 16))

# %%
# x = x.iloc[:,:-3]
x
# Out:
#        Years in current job  Monthly Debt  Years of Credit History  \
# 0                  0.526941     -1.086776                -0.142895
# 1                  1.095141      1.215813                 0.413014
# 2                  0.526941      0.879996                -0.470738
# 3                 -0.893559     -0.797558                -0.884106
# 4                 -0.325359      0.178031                -1.725096
# ...                     ...           ...                      ...
# 99995              0.242841     -1.333742                 0.584062
# 99996             -1.461759     -0.439463                -1.254712
# 99997             -0.041259     -0.914513                 0.085170
# 99998              0.811041     -0.703411                -0.456484
# 99999              1.095141     -0.766711                -0.741566
#
#        Months since last delinquent  Number of Open Accounts  \
# 0                          0.013126                -1.022634
# ...

# %%
# x = x.drop('Number of Credit Problems',axis = 1)

# %%
x = newtrain
y = train['Loan Status']
xtest = newtest

# %%
x.shape,y.shape,xtest.shape
# Out:
# ((100000, 16), (100000,), (10000, 16))

# %%
decision_tree_classification = DecisionTreeClassifier(criterion = 'entropy', random_state = 10)

# fit the model using fit() on train data
decision_tree = decision_tree_classification.fit(x, y)

# %%
train_pred = decision_tree.predict(x)

    # return the performace measures on train set
classification_report(y, train_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     77361\n           1       1.00      1.00      1.00     22639\n\n    accuracy                           1.00    100000\n   macro avg       1.00      1.00      1.00    100000\nweighted avg       1.00      1.00      1.00    100000\n'

# %%
from lightgbm import LGBMRegressor,LGBMClassifier
lgbm = DecisionTreeClassifier()
pred = lgbm.fit(x,y).predict(x)
classification_report(y, pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     77361\n           1       1.00      1.00      1.00     22639\n\n    accuracy                           1.00    100000\n   macro avg       1.00      1.00      1.00    100000\nweighted avg       1.00      1.00      1.00    100000\n'

# %%
# create a generalized function to calculate the metrics values for train set
def get_train_report(model):
    
    # for training set:
    # train_pred: prediction made by the model on the train dataset 'X_train'
    # y_train: actual values of the target variable for the train dataset

    # predict the output of the target variable from the train data 
    train_pred = model.predict(x)

    # return the performace measures on train seta
    return(classification_report(y, train_pred))

# %%
# create a generalized function to calculate the metrics values for test set
def get_test_report(model):
    
    # for test set:
    # test_pred: prediction made by the model on the test dataset 'X_test'
    # y_test: actual values of the target variable for the test dataset

    # predict the output of the target variable from the test data 
    test_pred = model.predict(newtest)

    # return the performace measures on test set
    return(classification_report(y, test_pred))

# %%
train_report = get_train_report(lgbm)

# print the performance measures
print(train_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     77361
#            1       1.00      1.00      1.00     22639
#
#     accuracy                           1.00    100000
#    macro avg       1.00      1.00      1.00    100000
# weighted avg       1.00      1.00      1.00    100000

# %%
test_report = get_test_report(lgbm)

# print the performance measures
print(test_report)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [480], in <cell line: 1>()
# ----> 1 test_report = get_test_report(lgbm)
#       3 # print the performance measures
#       4 print(test_report)
#
# Input In [478], in get_test_report(model)
#       9 test_pred = model.predict(newtest)
#      11 # return the performace measures on test set
# ---> 12 return(classification_report(y, test_pred))
#
# File D:\New folder\lib\site-packages\sklearn\metrics\_classification.py:2132, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2017 def classification_report(
#    2018     y_true,
#    2019     y_pred,
#    (...)
#    2026     zero_division="warn",
#    2027 ):
#    2028     """Build a text report showing the main classification metrics.
#    2029
# ...

# %%
x
# Out:
#        Years in current job  Monthly Debt  Years of Credit History  \
# 0                  0.526941     -1.086776                -0.142895
# 1                  1.095141      1.215813                 0.413014
# 2                  0.526941      0.879996                -0.470738
# 3                 -0.893559     -0.797558                -0.884106
# 4                 -0.325359      0.178031                -1.725096
# ...                     ...           ...                      ...
# 99995              0.242841     -1.333742                 0.584062
# 99996             -1.461759     -0.439463                -1.254712
# 99997             -0.041259     -0.914513                 0.085170
# 99998              0.811041     -0.703411                -0.456484
# 99999              1.095141     -0.766711                -0.741566
#
#        Months since last delinquent  Number of Open Accounts  \
# 0                          0.013126                -1.022634
# ...

# %%
X = x
y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42,stratify=df['clusters'])

# %% [raw]
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier

# %%
lg=LogisticRegression()
rf=RandomForestClassifier()
gbm=GradientBoostingClassifier()
xgb=XGBClassifier()
lgbm=LGBMClassifier(n_estimators=500,max_depth=10,random_state=10,learning_rate=0.01)
cboost=CatBoostClassifier()

# %%
from sklearn.metrics import accuracy_score
for model,name in zip([lg,rf,gbm,xgb,lgbm,cboost],['lg','rf','gbm','xgb','lgbm','cboost']):
    model.fit(x_train,y_train)
    print(name,'model generates accuracy score of',accuracy_score(y_test,model.predict(x_test)))
# Out:
# lg model generates accuracy score of 0.77325
# rf model generates accuracy score of 0.7762
# gbm model generates accuracy score of 0.77375
# xgb model generates accuracy score of 0.77345
# lgbm model generates accuracy score of 0.77385
# Learning rate set to 0.06692
# 0:	learn: 0.6686968	total: 189ms	remaining: 3m 8s
# 1:	learn: 0.6489029	total: 209ms	remaining: 1m 44s
# 2:	learn: 0.6310937	total: 229ms	remaining: 1m 15s
# 3:	learn: 0.6161737	total: 247ms	remaining: 1m 1s
# 4:	learn: 0.6011033	total: 262ms	remaining: 52.2s
# 5:	learn: 0.5902710	total: 277ms	remaining: 45.9s
# 6:	learn: 0.5806465	total: 292ms	remaining: 41.4s
# 7:	learn: 0.5729777	total: 307ms	remaining: 38.1s
# 8:	learn: 0.5657267	total: 321ms	remaining: 35.4s
# 9:	learn: 0.5587105	total: 336ms	remaining: 33.3s
# 10:	learn: 0.5538418	total: 351ms	remaining: 31.5s
# 11:	learn: 0.5494272	total: 367ms	remaining: 30.2s
# 12:	learn: 0.5454561	total: 382ms	remaining: 29s
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier()
tree_gin = DecisionTreeClassifier(criterion = 'gini')
tree_ent = DecisionTreeClassifier(criterion = 'entropy')
#svm_lin = svm.SVC(kernel = 'linear')
# svm_rbf = svm.SVC(kernel = 'rbf')
log = LogisticRegression()
rf = RandomForestClassifier()
xgb = XGBClassifier()

models = [knn,tree_gin,tree_ent,log,rf,xgb,lgbm]#,svm_rbf,svm_lin]

# %%
def model_fit_predict(model,xtrain, xtest, ytrain, ytest):
    model = model.fit(xtrain,ytrain) #fitting
    y_pred = model.predict(xtest) #predicting
    model_acurracy=accuracy_score(ytest, y_pred) #Evaluating
    accuracy.append(model_acurracy)
    
accuracy=[]

for i in models:
    model_fit_predict(i,x_train, x_test, y_train, y_test)
    
#print(accuracy)

#Visulization for the best model 
model_eval = pd.DataFrame(accuracy, 
                          index=['knn','tree_gin','tree_ent','log','rf','xgb','lgbm'],
                         columns= ['Accuracy'])
print('--- Accuracy Scores---')
model_eval.sort_values(by='Accuracy', ascending=False)
# Out:
# --- Accuracy Scores---
#           Accuracy
# rf         0.77515
# lgbm       0.77385
# xgb        0.77345
# log        0.77325
# knn        0.74070
# tree_ent   0.71705
# tree_gin   0.71630

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
model  = KMeans(random_state = 42)
visual = KElbowVisualizer(estimator = model,k=(2,10))

# %%
visual.fit(x)
visual.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
params = {'learning_rate':[0.001,0.01,0.1,1,10],
         'n_estimators':[200,250,300,400,500],
         'max_depth':[4,5,6,7,8]}
gscv = GridSearchCV(estimator=GradientBoostingClassifier(),
                   param_grid=params,
                   scoring='f1',
                   cv=3,
                   verbose=3)

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
smote_xsamp,smote_y=smote.fit_resample(x,y)

# %%
from sklearn.model_selection import train_test_split
sx_train, sx_test, sy_train, sy_test = train_test_split(X_pca,smote_y, test_size=0.20, random_state=42)

# %%
from sklearn.metrics import accuracy_score
for model,name in zip([lg,rf,gbm,xgb,lgbm,cboost],['lg','rf','gbm','xgb','lgbm','cboost']):
    model.fit(sx_train,sy_train)
    print(name,'model generates accuracy score of',accuracy_score(sy_test,model.predict(sx_test)))
# Out:
# lg model generates accuracy score of 0.5715947649054774
# rf model generates accuracy score of 0.8472451122960091
# gbm model generates accuracy score of 0.5985458070770723
# xgb model generates accuracy score of 0.6411375020197124
# lgbm model generates accuracy score of 0.6164485377282275
# Learning rate set to 0.080629
# 0:	learn: 0.6886983	total: 178ms	remaining: 2m 57s
# 1:	learn: 0.6849603	total: 209ms	remaining: 1m 44s
# 2:	learn: 0.6821425	total: 237ms	remaining: 1m 18s
# 3:	learn: 0.6793466	total: 259ms	remaining: 1m 4s
# 4:	learn: 0.6771033	total: 285ms	remaining: 56.7s
# 5:	learn: 0.6750353	total: 307ms	remaining: 50.8s
# 6:	learn: 0.6733554	total: 338ms	remaining: 47.9s
# 7:	learn: 0.6720482	total: 363ms	remaining: 45s
# 8:	learn: 0.6707700	total: 395ms	remaining: 43.5s
# 9:	learn: 0.6697100	total: 424ms	remaining: 42s
# 10:	learn: 0.6688406	total: 451ms	remaining: 40.5s
# 11:	learn: 0.6681548	total: 474ms	remaining: 39s
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
kf = KFold(n_splits=4)
mae_train = []
mae_test = []
for train_index, test_index in kf.split(X_pca):
    
   x_train, x_test = X_pca.iloc[train_index], X_pca.iloc[test_index]
   y_train, y_test = smote_y[train_index], smote_y[test_index]
   model = RandomForestClassifier()
   model.fit(x_train, y_train)
   y_train_pred = model.predict(x_train)
   y_test_pred = model.predict(x_test)
   mae_train.append(mean_absolute_error(y_train, y_train_pred))
   mae_test.append(mean_absolute_error(y_test, y_test_pred))

# %%
folds = range(1, kf.get_n_splits() + 1)
plt.plot(folds, mae_train, 'o-', color='green', label='train')
plt.plot(folds, mae_test, 'o-', color='red', label='test')
plt.legend()
plt.grid()
plt.xlabel('Number of fold')



plt.ylabel('Mean Absolute Error')
plt.show()

# %%
model = KNeighborsClassifier(n_neighbors=2)
test_model(model, x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 model = KNeighborsClassifier(n_neighbors=2)
# ----> 2 test_model(model, x,y)
#
# NameError: name 'test_model' is not defined

# %%
# create a dictionary with hyperparameters and its values
# pass the criteria 'entropy' and 'gini' to the parameter, 'criterion' 
# pass a list of values to 'n_estimators' to build the different number of trees in the random forest
# pass a list of values to 'max_depth' that assigns maximum depth of the tree
# 'max_features' assigns maximum number of features to consider for the best split. We pass the string 'sqrt' and 'log2'
# 'sqrt' considers maximum number of features equal to the square root of total features
# 'log2' considers maximum number of features equal to the log of total features with base 2
# pass a list of values to 'min_samples_split' that assigns minimum number of samples to split an internal node
# pass a list of values to 'min_samples_leaf' that assigns minimum number of samples required at the terminal/leaf node
# pass a list of values to 'max_leaf_nodes' that assigns maximum number of leaf nodes in the tree
tuned_paramaters = [{'criterion': ['entropy', 'gini'],
                     'n_estimators': [10, 50, 90],
                     'max_depth': [10, 15],
                     
                     'min_samples_leaf': [1, 5, 9],
                     'max_leaf_nodes': [2, 5, 8, 11]}]
 
# instantiate the 'RandomForestClassifier' 
# pass the 'random_state' to obtain the same samples for each time you run the code
random_forest_classification = RandomForestClassifier(random_state = 10)

# use GridSearchCV() to find the optimal value of the hyperparameters
# estimator: pass the random forest classifier model
# param_grid: pass the list 'tuned_parameters'
# cv: number of folds in k-fold i.e. here cv = 5
rf_grid = GridSearchCV(estimator = random_forest_classification, 
                       param_grid = tuned_paramaters, 
                       cv = 3)

# use fit() to fit the model on the train set
rf_grid_model = rf_grid.fit(smote_xsamp,smote_y)

# get the best parameters
print('Best parameters for random forest classifier: ', rf_grid_model.best_params_, '\n')
# Out:
# Best parameters for random forest classifier:  {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 11, 'min_samples_leaf': 1, 'n_estimators': 50}

# %%
cov_mat = np.cov(smote_xsamp.T)

# as 'cov_mat' is a numpy array, select first five observations with [0:5]
print(cov_mat[0:5])
# Out:
# [[ 1.00011845e+00  1.01457890e-01  2.37234522e-01  2.73312941e-03
#    3.83040385e-02  8.07609206e-02  3.08291757e-03  5.18733212e-02
#    1.84229896e-02 -4.53601515e-03 -1.74636275e-02 -2.56756227e-02
#    3.72309835e-04  2.10327520e-03  2.74974834e-03 -1.26920407e-02]
#  [ 1.01457890e-01  9.45606992e-01  1.88611534e-01 -4.13168004e-02
#    4.00319879e-01  4.37205783e-01  3.68267870e-02 -7.13905536e-02
#    2.57924010e-02 -6.45289664e-02 -6.53692780e-02 -8.08796616e-02
#   -3.01226587e-03  1.30003670e-02  9.33752259e-02 -4.79668080e-02]
#  [ 2.37234522e-01  1.88611534e-01  9.81506321e-01 -3.16030198e-02
#    1.27761588e-01  1.98312813e-01  2.90849755e-02  6.45116488e-02
#    1.56621369e-02 -2.99445863e-02 -2.35856314e-02 -2.34982655e-02
#   -2.25519546e-02 -9.17632725e-03  2.95437235e-02 -2.00553365e-02]
#  [ 2.73312941e-03 -4.13168004e-02 -3.16030198e-02  9.88872004e-01
#   -2.05630249e-02 -1.51075229e-02 -4.20976169e-03  8.15455080e-02
# ...

# %%
eig_val, eig_vec = np.linalg.eig(cov_mat)

print('Eigenvalues:','\n','\n', eig_val,"\n")

print('Eigenvectors:','\n','\n',eig_vec,'\n')
# Out:
# Eigenvalues:
#
#  [1.8606183  1.18352799 1.02383657 1.00686818 0.89291926 0.77681104
#  0.71777259 0.64734068 0.42865936 0.27593856 0.2156768  0.1945013
#  0.06179238 0.05222065 0.03527898 0.04209827]
#
# Eigenvectors:
#
#  [[ 2.34504329e-01 -5.65983058e-01  3.28964897e-01 -1.80664784e-01
#   -3.29589901e-01  4.05549831e-01  4.56087739e-01  5.15841484e-03
#   -3.98501406e-02  2.48106643e-02  1.40294700e-02 -1.09715919e-02
#    4.84696990e-03  1.09244429e-02  1.84483740e-03  1.83907396e-03]
#  [ 5.70572064e-01  1.46893725e-01 -1.37100818e-01  8.52710089e-02
#    7.06829561e-02  8.09962402e-02  5.58911235e-02  3.30968293e-01
#    6.82867162e-01 -3.85369321e-02  1.28852642e-01 -2.99093445e-02
#   -1.18062375e-01 -3.76625040e-02  2.20907930e-02  3.80296461e-02]
#  [ 3.69436557e-01 -4.34361344e-01  2.31413832e-01 -1.22196645e-01
#   -1.12278185e-02 -3.26765512e-01 -6.51654842e-01 -2.62433350e-01
#    6.17031651e-02 -2.25005941e-02  8.41909350e-03  2.55623530e-02
# ...

# %%
eig_val = list(eig_val)

# 'sort(reverse = True)' will sort the eigenvalues in the descending order
eig_val.sort(reverse = True)

# print the sorted list
print(eig_val)
# Out:
# [1.860618301133913, 1.1835279899967042, 1.0238365662768367, 1.0068681794142083, 0.8929192618654812, 0.7768110432193189, 0.7177725946834796, 0.6473406796109388, 0.4286593642979648, 0.27593855686594654, 0.21567679954313104, 0.19450129669430247, 0.06179238092384601, 0.0522206450338684, 0.042098272981274804, 0.0352789808716434]

# %%
# 'bp' represents blue color and pentagonal shape of points
plt.plot(eig_val,'bp')            

# plot a line plot
plt.plot(eig_val) 
# set the axes and plot labels
# set the fontsize using 'fontsize'
plt.title('Scree Plot', fontsize = 15)
plt.xlabel('Principal Components', fontsize = 15)    
plt.ylabel('Explained Variance', fontsize = 15)      
# use 'annonate' function to draw an arrow between points xy and xytext
# 's' is a argument to write text
# we can change the facecolor and arrowstyle; this is only for representation purpose
# plt.annotate(s ='Elbow Point', xy=(2.05,1.2), xytext=(2, 1.8), arrowprops=dict(facecolor='black', arrowstyle = 'simple'))
# display the plot
plt.show()

# %%
percent_var = []

# use a 'for' loop to calculate the percentage of variation for each component
for i in eig_val:
    variation = (i/sum(eig_val))*100
    
    # add the values to the list 'percent_var'
    percent_var.append(variation)
    
# print the percentage of variation
percent_var
# Out:
# [19.76046925760627,
#  12.569514363904558,
#  10.873531116187001,
#  10.693320437432634,
#  9.483139885738128,
#  8.250026740653682,
#  7.62301611381085,
#  6.875002568153958,
#  4.552524386669106,
#  2.930571717269879,
#  2.2905690889709325,
#  2.0656772490897364,
#  0.6562584291769114,
#  0.5546029780397487,
#  0.4470995628377005,
#  0.37467610445889893]

# %%
np.cumsum(percent_var)
# Out:
# array([ 19.76046926,  32.32998362,  43.20351474,  53.89683518,
#         63.37997506,  71.6300018 ,  79.25301792,  86.12802048,
#         90.68054487,  93.61111659,  95.90168568,  97.96736293,
#         98.62362135,  99.17822433,  99.6253239 , 100.        ])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=11)
pca.fit(smote_xsamp)
X_pca = pca.transform(smote_xsamp)
X_pca = pd.DataFrame(X_pca)
