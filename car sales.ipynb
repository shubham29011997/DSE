# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train  =  pd.read_csv('~/Downloads/Train_cars.csv')
test  =  pd.read_csv('~/Downloads/Test_cars.csv')

# %%
train.shape
# Out:
# (22500, 13)

# %%
test.shape
# Out:
# (52500, 12)

# %%
train['spl'] = 'train'
test['spl'] = 'test'

# %%
df=pd.concat([train,test],ignore_index=True)

# %%
df.head()
# Out:
#                       Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII   Bangalore  2012              33715    Diesel
# 1      Honda City 1.5 V AT       Delhi  2013              73977    Diesel
# 2        Honda CR-V RVi MT       Delhi  2007              16460       CNG
# 3  Skoda Yeti Ambition 4X2     Kolkata  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG  Coimbatore  2013              41656    Petrol
#
#   Transmission Owner_Type     Mileage   Engine     Power  Seats   New_Price  \
# 0       Manual      First  16.46 kmpl  1248 CC   100 bhp    5.0  43.65 Lakh
# 1       Manual      First   18.6 kmpl  2993 CC    61 bhp    4.0         NaN
# 2       Manual      Third   15.3 kmpl  1599 CC   140 bhp    5.0         NaN
# 3       Manual      First  25.47 kmpl  1196 CC  86.8 bhp    5.0         NaN
# 4    Automatic      First  19.12 kmpl  1999 CC   115 bhp    7.0  13.26 Lakh
#
#    Price    spl
# 0  25.53  train
# 1   4.58  train
# ...

# %%
df.shape
# Out:
# (75000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               75000 non-null  object
#  1   Location           75000 non-null  object
#  2   Year               75000 non-null  int64
#  3   Kilometers_Driven  75000 non-null  int64
#  4   Fuel_Type          75000 non-null  object
#  5   Transmission       75000 non-null  object
#  6   Owner_Type         75000 non-null  object
#  7   Mileage            74659 non-null  object
#  8   Engine             74894 non-null  object
#  9   Power              74683 non-null  object
#  10  Seats              74662 non-null  float64
#  11  New_Price          13066 non-null  object
#  12  Price              22500 non-null  float64
#  13  spl                75000 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
df1 = df.copy()

# %%
df1.isnull().sum()*100/df1.isnull().count()
# Out:
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.454667
# Engine                0.141333
# Power                 0.422667
# Seats                 0.450667
# New_Price            82.578667
# Price                70.000000
# spl                   0.000000
# dtype: float64

# %%
# df1.Mileage = df1.Mileage[0] = (float)

# %%
 df1['Mileage'].values
# Out:
# array(['16.46 kmpl', '18.6 kmpl', '15.3 kmpl', ..., '22.0 kmpl',
#        '10.98 kmpl', '14.0 kmpl'], dtype=object)

# %%
# x =[]
# for i in df1.Mileage.values:
#     x.append(i[0][0])
# x[0][0]

# %%
# df1["Mileage"]= df1["Mileage"].str.split(" ", n = 1, expand = False)

# %%
df1.Mileage
# Out:
# 0        16.46 kmpl
# 1         18.6 kmpl
# 2         15.3 kmpl
# 3        25.47 kmpl
# 4        19.12 kmpl
#             ...
# 74995    16.09 kmpl
# 74996     12.6 kmpl
# 74997     22.0 kmpl
# 74998    10.98 kmpl
# 74999     14.0 kmpl
# Name: Mileage, Length: 75000, dtype: object

# %%
# a = df1.Mileage
# numbers = []
# c=1
# for item in range(len(df1.Mileage)):
#     numbers.append(df1.Mileage[item][0])
#     c+=1
# print(numbers)

# %%
# df1.Mileage[1][0]

# %%
new = df1["Power"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df1["Power"]= new[0]
 
# making separate last name column from new data frame
df1["Punit"]= new[1]

# %%
new = df1["Mileage"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df1["Mileage"]= new[0]
 
# making separate last name column from new data frame
df1["Munit"]= new[1]

# %%
new = df1["New_Price"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df1["New_Price"]= new[0]
 
# making separate last name column from new data frame
df1["Nunit"]= new[1]

# %%
new = df1["Engine"].str.split(" ", n = 1, expand = True)
 
# making separate first name column from new data frame
df1["Engine"]= new[0]
 
# making separate last name column from new data frame
df1["Eunit"]= new[1]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               75000 non-null  object
#  1   Location           75000 non-null  object
#  2   Year               75000 non-null  int64
#  3   Kilometers_Driven  75000 non-null  int64
#  4   Fuel_Type          75000 non-null  object
#  5   Transmission       75000 non-null  object
#  6   Owner_Type         75000 non-null  object
#  7   Mileage            74659 non-null  object
#  8   Engine             74894 non-null  object
#  9   Power              74683 non-null  object
#  10  Seats              74662 non-null  float64
#  11  New_Price          13066 non-null  object
#  12  Price              22500 non-null  float64
#  13  spl                75000 non-null  object
#  14  Punit              74683 non-null  object
#  15  Munit              74659 non-null  object
# ...

# %%
df1.drop('Punit',axis= 1,inplace=True)

# %%
df1.Power =df1.Power.replace('null',np.nan)

# %%
df1.New_Price =df1.New_Price.astype(float)
df1.Power = df1.Power.astype(float)
df1.Mileage = df1.Mileage.astype(float)
df1.Engine = df1.Engine.astype(float)

# %%
df1.Year.value_counts().sort_index(ascending=False)
# Out:
# 2018      313
# 2017     3133
# 2016     2260
# 2015     4595
# 2014     8769
# 2013    13891
# 2012    10455
# 2011     8486
# 2010     8543
# 2009     8742
# 2008      967
# 2007     2451
# 2006     1055
# 2005      427
# 2004      443
# 2003      305
# 2002      130
# 2001       31
# 2000        4
# Name: Year, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Name                     0
# Location                 0
# Year                     0
# Kilometers_Driven        0
# Fuel_Type                0
# Transmission             0
# Owner_Type               0
# Mileage                  0
# Engine                   0
# Power                    0
# Seats                    0
# New_Price                0
# Price                52500
# spl                      0
# Munit                    0
# Nunit                    0
# Eunit                  106
# dtype: int64

# %%
df1.Mileage = df1.Mileage.fillna(df1.Mileage.median())
df1.Power = df1.Power.fillna(df1.Power.median())
df1.Engine = df1.Engine.fillna(df1.Engine.median())
df1.Seats = df1.Seats.fillna(df1.Seats.median())

# %%
df1.New_Price = df1.New_Price.fillna(10.15)

# %%
df1.Munit.mode()
# Out:
# 0    kmpl
# Name: Munit, dtype: object

# %%
df1.Munit = df1.Munit.fillna('kmpl')
df1.Nunit = df1.Nunit.fillna('lakh')

# %%
df1.corr()
# Out:
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.174120  0.030517  0.117262  0.097441
# Kilometers_Driven -0.174120           1.000000 -0.070158 -0.068724 -0.072746
# Mileage            0.030517          -0.070158  1.000000 -0.011199  0.004606
# Engine             0.117262          -0.068724 -0.011199  1.000000  0.107717
# Power              0.097441          -0.072746  0.004606  0.107717  1.000000
# Seats              0.039931           0.038882 -0.037032  0.129016  0.061922
# New_Price          0.096756          -0.071393 -0.019715  0.067189  0.066130
# Price              0.111298          -0.072443 -0.039527  0.213773  0.130066
#
#                       Seats  New_Price     Price
# Year               0.039931   0.096756  0.111298
# Kilometers_Driven  0.038882  -0.071393 -0.072443
# Mileage           -0.037032  -0.019715 -0.039527
# Engine             0.129016   0.067189  0.213773
# ...

# %%
df1.describe()
# Out:
#                Year  Kilometers_Driven       Mileage        Engine  \
# count  75000.000000       75000.000000  75000.000000  75000.000000
# mean    2011.821053       48859.175787     18.291913   1641.480520
# std        2.685890       21583.406967      5.037724    669.723866
# min     2000.000000         171.000000      0.000000     72.000000
# 25%     2010.000000       35710.750000     14.670000   1197.000000
# 50%     2012.000000       47861.000000     17.800000   1495.000000
# 75%     2014.000000       59548.250000     21.760000   1995.000000
# max     2018.000000      255022.000000     33.540000   5998.000000
#
#               Power         Seats    New_Price         Price
# count  75000.000000  75000.000000  75000.00000  22500.000000
# mean     115.965784      5.354600     11.41437      6.359158
# std       63.563301      0.846271      8.12428      7.302764
# min       34.200000      4.000000      1.00000      0.440000
# ...

# %%
df1.groupby(df1['Munit'])['Nunit'].describe()
# Out:
#        count unique   top   freq
# Munit
# km/kg   7056      3  lakh   6392
# kmpl   67944      3  lakh  55542

# %%
df1[df1.Nunit == 'Cr'].Location.value_counts()
# Out:
# Hyderabad     70
# Coimbatore    48
# Kochi         36
# Delhi         34
# Mumbai        29
# Jaipur        28
# Chennai       17
# Ahmedabad     16
# Kolkata       14
# Bangalore     12
# Pune           5
# Name: Location, dtype: int64

# %%
# df1.drop('Name',axis = 1,inplace=True)
df1.drop(['Munit','Nunit','Name','Eunit'],axis = 1,inplace=True)

# %%
df1.drop('Kilometers_Driven',axis = 1).boxplot()
# Out:
# <AxesSubplot:>

# %%
# q3 = df1.Kilometers_Driven.quantile(0.75)
# q1 = df1.Kilometers_Driven.quantile(0.25)
# iqr = q3-q1
# low = q1-3.5*iqr
# upp = q3+3.5*iqr
# df1.Kilometers_Driven = df1.Kilometers_Driven[~((df1.Kilometers_Driven < low) | (df1.Kilometers_Driven > upp)).any(axis=1)]

# %%
# df1.drop(['Owner_Type','Fuel_Type'],axis = 1,inplace=True)

# %%
df1.std()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10356\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# Year                     2.685890
# Kilometers_Driven    21583.406967
# Mileage                  5.037724
# Engine                 669.723866
# Power                   63.563301
# Seats                    0.846271
# New_Price                8.124280
# Price                    7.302764
# dtype: float64

# %%
num = df1.select_dtypes(np.number)

# %%
cat = df1.select_dtypes(object)
cat.drop('spl',axis = 1,inplace=True)

# %%
num.std()
# Out:
# Year                     2.685890
# Kilometers_Driven    21583.406967
# Mileage                  5.037724
# Engine                 669.723866
# Power                   63.563301
# Seats                    0.846271
# New_Price                8.124280
# Price                    7.302764
# dtype: float64

# %%
num.boxplot()
# Out:
# <AxesSubplot:>

# %%
num.head()
# Out:
#    Year  Kilometers_Driven  Mileage  Engine  Power  Seats  New_Price  Price
# 0  2012              33715    16.46  1248.0  100.0    5.0      43.65  25.53
# 1  2013              73977    18.60  2993.0   61.0    4.0      10.15   4.58
# 2  2007              16460    15.30  1599.0  140.0    5.0      10.15   2.37
# 3  2009              35048    25.47  1196.0   86.8    5.0      10.15   1.20
# 4  2013              41656    19.12  1999.0  115.0    7.0      13.26  33.04

# %%
# cat.dop

# %%
cat.head()
# Out:
#      Location Fuel_Type Transmission Owner_Type
# 0   Bangalore    Diesel       Manual      First
# 1       Delhi    Diesel       Manual      First
# 2       Delhi       CNG       Manual      Third
# 3     Kolkata    Petrol       Manual      First
# 4  Coimbatore    Petrol    Automatic      First

# %%
cat = pd.get_dummies(cat,drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
n =scale.fit_transform(num)
num = pd.DataFrame(n,columns=num.columns)

# %%
num
# Out:
#            Year  Kilometers_Driven   Mileage    Engine     Power     Seats  \
# 0      0.066625          -0.701663 -0.363641 -0.587530 -0.251181 -0.419017
# 1      0.438944           1.163764  0.061156  2.018038 -0.864747 -1.600679
# 2     -1.794967          -1.501125 -0.593906 -0.063430  0.378117 -0.419017
# 3     -1.050330          -0.639902  1.424877 -0.665175 -0.458849 -0.419017
# 4      0.438944          -0.333739  0.164378  0.533835 -0.015194  1.944307
# ...         ...                ...       ...       ...       ...       ...
# 74995  0.811262           0.494542 -0.437088 -0.587530 -0.329843  3.125969
# 74996  1.928218           0.336503 -1.129866 -0.075376 -0.474582 -0.419017
# 74997  0.066625           0.394094  0.736069  2.018038  0.917740 -0.419017
# 74998  0.066625          -0.720566 -1.451441  0.527862 -0.062392 -0.419017
# 74999  1.928218          -0.227499 -0.851960  0.233709  5.854584 -0.419017
#
#        New_Price     Price
# 0       3.967840  2.625207
# ...

# %%
df2 = pd.concat([num,cat],axis = 1)

# %%
df2.drop('Price',axis = 1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(df2.values,i)for i in range(df2.shape[1])]

# %%
pd.DataFrame({'VIF':vif[:]},index = df2.columns)
# Out:
#                                 VIF
# Year                       1.113315
# Kilometers_Driven          1.150422
# Mileage                    1.016319
# Engine                     1.109760
# Power                      1.047277
# Seats                      1.090782
# New_Price                  1.033033
# Location_Bangalore         1.559661
# Location_Chennai           2.064484
# Location_Coimbatore        1.508504
# Location_Delhi             1.699310
# Location_Hyderabad         2.838956
# Location_Jaipur            1.884533
# Location_Kochi             1.528140
# Location_Kolkata           2.854221
# Location_Mumbai            3.267834
# Location_Pune              1.447582
# Fuel_Type_Diesel           4.698800
# Fuel_Type_Electric         1.005441
# Fuel_Type_LPG              1.006673
# Fuel_Type_Petrol           4.880934
# Transmission_Manual        5.052619
# Owner_Type_Fourth & Above  1.008490
# Owner_Type_Second          1.135977
# Owner_Type_Third           1.072436

# %%
newtrain=df3.iloc[:train.shape[0]]
newtest=df3.iloc[train.shape[0]:]

# %%
newtest.shape,newtrain.shape
# Out:
# ((52500, 19), (22500, 19))

# %%
x = newtrain
y = train['Price']
xtest = newtest

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.191
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     278.7
# Date:                Sat, 01 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:58:30   Log-Likelihood:                -74281.
# No. Observations:               22500   AIC:                         1.486e+05
# Df Residuals:                   22480   BIC:                         1.488e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.3900      0.044    145.775      0.000       6.304       6.476
# ...

# %%
x.drop('const',axis = 1,inplace = True)

# %%
from lightgbm import LGBMRegressor,LGBMClassifier
lgbm = LGBMRegressor()
pred = lgbm.fit(x,y).predict(xtest)
pred
# Out:
# array([19.75563231,  9.2027759 ,  8.24098797, ...,  7.58538063,
#         8.56267409,  4.05978379])

# %%
lgbm.score(xtest,pred)
# Out:
# 1.0

# %%
submission = pd.DataFrame({'Name':test.Name,'Price':model})
submission.to_csv('model.csv',index = False)

# %%
from xgboost import XGBRegressor
model_xg = XGBRegressor(n_estimators=400, max_depth=7)
model = model_xg.fit(x,y).predict(xtest)
model
# Out:
# array([20.999691 , 15.133087 ,  7.7314057, ...,  4.970589 ,  7.3466043,
#         7.578268 ], dtype=float32)

# %%
model_xg.score(xtest,model)
# Out:
# 1.0

# %%
logreg = sm.Logit(y, x).fit()

# print the summary of the model
print(logreg.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 logreg = sm.Logit(y, x).fit()
#       3 # print the summary of the model
#       4 print(logreg.summary())
#
# File D:\New folder\lib\site-packages\statsmodels\discrete\discrete_model.py:465, in BinaryModel.__init__(self, endog, exog, check_rank, **kwargs)
#     463 if not issubclass(self.__class__, MultinomialModel):
#     464     if not np.all((self.endog >= 0) & (self.endog <= 1)):
# --> 465         raise ValueError("endog must be in the unit interval.")
#     467     if (not self._continuous_ok and
#     468             np.any(self.endog != np.round(self.endog))):
#     469         raise ValueError("endog must be binary, either 0 or 1")
#
# ValueError: endog must be in the unit interval.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,GradientBoostingRegressor
from xgboost import XGBClassifier
from catboost import CatBoostClassifier,CatBoostRegressor
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from lightgbm import LGBMRegressor,LGBMClassifier
lgbm = GradientBoostingRegressor()
pred2 = lgbm.fit(x,y).predict(xtest)
pred2
# Out:
# array([16.08940099, 12.83899   ,  8.11407792, ...,  7.83801542,
#         7.27607741,  5.68934654])

# %%
model_cat = CatBoostRegressor(n_estimators=600,max_depth=9)
pred3 = model_cat.fit(x,y).predict(xtest)
pred3
# Out:
# Learning rate set to 0.101435
# 0:	learn: 7.1711197	total: 37.9ms	remaining: 22.7s
# 1:	learn: 7.0574685	total: 73.6ms	remaining: 22s
# 2:	learn: 6.9581790	total: 106ms	remaining: 21.2s
# 3:	learn: 6.8753215	total: 137ms	remaining: 20.4s
# 4:	learn: 6.8051508	total: 167ms	remaining: 19.9s
# 5:	learn: 6.7452469	total: 198ms	remaining: 19.6s
# 6:	learn: 6.6968161	total: 235ms	remaining: 19.9s
# 7:	learn: 6.6490739	total: 268ms	remaining: 19.8s
# 8:	learn: 6.6056487	total: 300ms	remaining: 19.7s
# 9:	learn: 6.5675854	total: 331ms	remaining: 19.5s
# 10:	learn: 6.5365724	total: 361ms	remaining: 19.3s
# 11:	learn: 6.5097340	total: 392ms	remaining: 19.2s
# 12:	learn: 6.4832461	total: 431ms	remaining: 19.4s
# 13:	learn: 6.4596621	total: 463ms	remaining: 19.4s
# 14:	learn: 6.4347880	total: 496ms	remaining: 19.3s
# 15:	learn: 6.4149954	total: 526ms	remaining: 19.2s
# 16:	learn: 6.3984501	total: 558ms	remaining: 19.2s
# 17:	learn: 6.3846763	total: 593ms	remaining: 19.2s
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=25)
data_pca = pca.fit_transform(df2)
data_pca = pd.DataFrame(data_pca,columns = range(1,26))

# %%
data_pca
# Out:
#              1         2         3         4         5         6         7   \
# 0      1.122911 -0.992230  2.823023  0.063794  2.302831 -0.504518 -0.660726
# 1      0.002739  0.333952  0.028602 -0.726845  0.414591  2.329104  1.737985
# 2     -0.419252 -0.350671  0.387182  0.557059 -0.769228  0.802185 -1.994951
# 3     -1.002906 -1.362925 -0.902716  0.274575  0.618659  0.094256 -0.944572
# 4      1.264133  0.755974 -0.542527 -0.566386  0.363045 -0.809992 -0.694854
# ...         ...       ...       ...       ...       ...       ...       ...
# 74995  0.588147  2.068659 -0.565890 -0.956698  0.225616 -2.355648 -0.290269
# 74996  0.139516  0.255828  0.149242 -1.259517 -1.557621 -0.349477  1.733855
# 74997  1.149484  0.570784 -0.829628  0.658404  0.259210  1.680362  0.721269
# 74998  0.362243  0.337677  0.919284 -0.583247 -1.067915  0.637459 -0.220849
# 74999  3.255047 -0.243178  0.568912  4.183058 -2.778577 -0.700135  1.353916
#
# ...

# %%
var  = pca.explained_variance_ratio_

# %%
var
# Out:
# array([1.67236101e-01, 1.39484981e-01, 1.16589640e-01, 1.06471615e-01,
#        1.05564308e-01, 9.81879272e-02, 9.45053597e-02, 4.44912391e-02,
#        2.07356256e-02, 1.81257036e-02, 1.70833830e-02, 1.30161224e-02,
#        1.02640748e-02, 8.19030117e-03, 8.01116868e-03, 7.12541850e-03,
#        6.04342406e-03, 5.65898025e-03, 5.29566212e-03, 4.74155357e-03,
#        2.40999472e-03, 3.49496593e-04, 2.53288270e-04, 8.76680105e-05,
#        7.69631479e-05])

# %%
add = 0
for i in range(25):
    add = add+var[i]
    print('total varinece upto pc%s is %.2f'%(i+1,add))
# Out:
# total varinece upto pc1 is 0.17
# total varinece upto pc2 is 0.31
# total varinece upto pc3 is 0.42
# total varinece upto pc4 is 0.53
# total varinece upto pc5 is 0.64
# total varinece upto pc6 is 0.73
# total varinece upto pc7 is 0.83
# total varinece upto pc8 is 0.87
# total varinece upto pc9 is 0.89
# total varinece upto pc10 is 0.91
# total varinece upto pc11 is 0.93
# total varinece upto pc12 is 0.94
# total varinece upto pc13 is 0.95
# total varinece upto pc14 is 0.96
# total varinece upto pc15 is 0.97
# total varinece upto pc16 is 0.98
# total varinece upto pc17 is 0.98
# total varinece upto pc18 is 0.99
# total varinece upto pc19 is 0.99
# total varinece upto pc20 is 1.00
# total varinece upto pc21 is 1.00
# total varinece upto pc22 is 1.00
# total varinece upto pc23 is 1.00
# total varinece upto pc24 is 1.00
# total varinece upto pc25 is 1.00

# %%
plt.plot(np.arange(1,26),var,marker = 'o')

# %%
df3 = data_pca.iloc[:,:-6]
df3
# Out:
#              1         2         3         4         5         6         7   \
# 0      1.122911 -0.992230  2.823023  0.063794  2.302831 -0.504518 -0.660726
# 1      0.002739  0.333952  0.028602 -0.726845  0.414591  2.329104  1.737985
# 2     -0.419252 -0.350671  0.387182  0.557059 -0.769228  0.802185 -1.994951
# 3     -1.002906 -1.362925 -0.902716  0.274575  0.618659  0.094256 -0.944572
# 4      1.264133  0.755974 -0.542527 -0.566386  0.363045 -0.809992 -0.694854
# ...         ...       ...       ...       ...       ...       ...       ...
# 74995  0.588147  2.068659 -0.565890 -0.956698  0.225616 -2.355648 -0.290269
# 74996  0.139516  0.255828  0.149242 -1.259517 -1.557621 -0.349477  1.733855
# 74997  1.149484  0.570784 -0.829628  0.658404  0.259210  1.680362  0.721269
# 74998  0.362243  0.337677  0.919284 -0.583247 -1.067915  0.637459 -0.220849
# 74999  3.255047 -0.243178  0.568912  4.183058 -2.778577 -0.700135  1.353916
#
# ...
